# %%
import pandas as pd

# %%
data = pd.read_csv('https://msss.gouv.qc.ca/professionnels/statistiques/documents/covid19/COVID19_Qc_RapportINSPQ_HistoVigie.csv', skiprows = [1])

data
# Out:
#             Date  Nb_Cas_Cumulatif  Nb_Nvx_Cas  Nb_Deces_Cumulatif_Total  \
# 0     2020-01-23                 0           0                         0
# 1     2020-01-24                 0           0                         0
# 2     2020-01-25                 0           0                         0
# 3     2020-01-26                 0           0                         0
# 4     2020-01-27                 0           0                         0
# ...          ...               ...         ...                       ...
# 996   2022-10-15           1215208         709                     16817
# 997   2022-10-16           1215856         648                     16821
# 998   2022-10-17           1216911        1055                     16824
# 999   2022-10-18           1217992        1081                     16830
# 1000  2022-10-19           1219020        1028                     16832
#
#       Nb_Deces_Cumulatif_CHCHSLD  Nb_Deces_Cumulatif_RPA  \
# ...

# %%
data['Date'] = pd.to_datetime(data['Date'])

# %%
data_2020 = data[data['Date'].dt.year < 2021]

data_march = data_2020[(data_2020['Date'].dt.month == 3) | (data_2020['Date'].dt.month == 4)][['Date', 'Nb_Nvx_Cas']]

lock1 = data_march[(data_march['Date'] > '2020-03-19') & (data_march['Date'] < '2020-04-15')]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

ax = sns.scatterplot(data = lock1, x = 'Date', y = 'Nb_Nvx_Cas')
ax.axvline(pd.to_datetime('2020-04-03'), color = 'red')
plt.ylabel('New Cases')
plt.xticks(rotation = 90)
plt.show()
